# %%
import os
from pathlib import Path
import numpy as np
import torch

# %%
# Training set OD
# directory1 = 'data/IDRID/A. Segmentation/1. Original Images/a. Training Set'
# directory2 = 'data/IDRID/A. Segmentation/2. All Segmentation Groundtruths/a. Training Set/5. Optic Disc'
# base_append_dir1 = 'A. Segmentation/1. Original Images/a. Training Set/'
# base_append_dir2 = 'A. Segmentation/2. All Segmentation Groundtruths/a. Training Set/5. Optic Disc/'

# %%
# # Testing set
directory1 = 'data/IDRID/A. Segmentation/1. Original Images/b. Testing Set'
directory2 = 'data/IDRID/A. Segmentation/2. All Segmentation Groundtruths/b. Testing Set/5. Optic Disc'
base_append_dir1 = 'A. Segmentation/1. Original Images/b. Testing Set/'
base_append_dir2 = 'A. Segmentation/2. All Segmentation Groundtruths/b. Testing Set/5. Optic Disc/'

# %%
# Training set SE
directory1 = 'data/IDRID/A. Segmentation/1. Original Images/a. Training Set'
directory2 = 'data/IDRID/A. Segmentation/2. All Segmentation Groundtruths/a. Training Set/4. Soft Exudates'
base_append_dir1 = 'A. Segmentation/1. Original Images/a. Training Set/'
base_append_dir2 = 'A. Segmentation/2. All Segmentation Groundtruths/a. Training Set/4. Soft Exudates/'

# %%
# testing set SE
directory1 = 'data/IDRID/A. Segmentation/1. Original Images/b. Testing Set'
directory2 = 'data/IDRID/A. Segmentation/2. All Segmentation Groundtruths/b. Testing Set/4. Soft Exudates'
base_append_dir1 = 'A. Segmentation/1. Original Images/b. Testing Set/'
base_append_dir2 = 'A. Segmentation/2. All Segmentation Groundtruths/b. Testing Set/4. Soft Exudates/'

# %%
# Training set HE
directory1 = 'data/IDRID/A. Segmentation/1. Original Images/a. Training Set'
directory2 = 'data/IDRID/A. Segmentation/2. All Segmentation Groundtruths/a. Training Set/3. Hard Exudates'
base_append_dir1 = 'A. Segmentation/1. Original Images/a. Training Set/'
base_append_dir2 = 'A. Segmentation/2. All Segmentation Groundtruths/a. Training Set/3. Hard Exudates/'

# %%
# testing set HE
directory1 = 'data/IDRID/A. Segmentation/1. Original Images/b. Testing Set'
directory2 = 'data/IDRID/A. Segmentation/2. All Segmentation Groundtruths/b. Testing Set/3. Hard Exudates'
base_append_dir1 = 'A. Segmentation/1. Original Images/b. Testing Set/'
base_append_dir2 = 'A. Segmentation/2. All Segmentation Groundtruths/b. Testing Set/3. Hard Exudates/'

# %%
# Training set Hae
directory1 = 'data/IDRID/A. Segmentation/1. Original Images/a. Training Set'
directory2 = 'data/IDRID/A. Segmentation/2. All Segmentation Groundtruths/a. Training Set/2. Haemorrhages'
base_append_dir1 = 'A. Segmentation/1. Original Images/a. Training Set/'
base_append_dir2 = 'A. Segmentation/2. All Segmentation Groundtruths/a. Training Set/2. Haemorrhages/'

# %%
# testing set Hae
directory1 = 'data/IDRID/A. Segmentation/1. Original Images/b. Testing Set'
directory2 = 'data/IDRID/A. Segmentation/2. All Segmentation Groundtruths/b. Testing Set/2. Haemorrhages'
base_append_dir1 = 'A. Segmentation/1. Original Images/b. Testing Set/'
base_append_dir2 = 'A. Segmentation/2. All Segmentation Groundtruths/b. Testing Set/2. Haemorrhages/'

# %%
# Training set MA
directory1 = 'data/IDRID/A. Segmentation/1. Original Images/a. Training Set'
directory2 = 'data/IDRID/A. Segmentation/2. All Segmentation Groundtruths/a. Training Set/1. Microaneurysms'
base_append_dir1 = 'A. Segmentation/1. Original Images/a. Training Set/'
base_append_dir2 = 'A. Segmentation/2. All Segmentation Groundtruths/a. Training Set/1. Microaneurysms/'

# %%
# testing set MA
directory1 = 'data/IDRID/A. Segmentation/1. Original Images/b. Testing Set'
directory2 = 'data/IDRID/A. Segmentation/2. All Segmentation Groundtruths/b. Testing Set/1. Microaneurysms'
base_append_dir1 = 'A. Segmentation/1. Original Images/b. Testing Set/'
base_append_dir2 = 'A. Segmentation/2. All Segmentation Groundtruths/b. Testing Set/1. Microaneurysms/'

# %%
# Classification file

# %%
orig_image_list = []
seg_image_list = []
overall_list = []

for files in os.listdir(directory1):
    
    op_seg_file = files.split('.')[0] + '_MA.tif'
    f_path = Path('data/IDRID/' + base_append_dir2 + '/' + op_seg_file)
    if f_path.is_file():
        orig_image_list.append(base_append_dir1 + files)
        seg_image_list.append(base_append_dir2 + op_seg_file)
        
        orig_img_path = base_append_dir1 + files
        seg_img_path = base_append_dir2 + op_seg_file
        
        overall_list.append(orig_img_path + ',' + seg_img_path + '\n')
        
    else:
    
        print(files, op_seg_file)

# %%
# text_file_name = 'data/IDRID/train_ma.txt'
# text_file = open(text_file_name,"w")
# text_file.writelines(overall_list)
# text_file.close()

# %%
overall_list[0]
# Out:
# 'A. Segmentation/1. Original Images/a. Training Set/IDRiD_44.jpg,A. Segmentation/2. All Segmentation Groundtruths/a. Training Set/1. Microaneurysms/IDRiD_44_MA.tif\n'

# %%
import cv2
import matplotlib.pyplot as plt

# %%
path = 'data/IDRID/' + overall_list[0].split(',')[0]
path2 = 'data/IDRID/' + overall_list[0].split(',')[1]
path2 = path2.strip('\n')
print(path)
print(path2)
image = cv2.imread(path)
image2 = cv2.imread(path2)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
# Out:
# data/IDRID/A. Segmentation/1. Original Images/a. Training Set/IDRiD_44.jpg
# data/IDRID/A. Segmentation/2. All Segmentation Groundtruths/a. Training Set/1. Microaneurysms/IDRiD_44_MA.tif

# %%
print(image.shape, image2.shape)
# Out:
# (2848, 4288, 3) (2848, 4288, 3)

# %%
def rgb2gray(rgb):
    return np.dot(rgb[...,:3], [0.2989, 0.5870, 0.1140])
image2_gray = rgb2gray(image2)
image2_gray.shape
# Out:
# (2848, 4288)

# %%
def scaleRadius(img, scale) :
    x=img[int(img.shape[0]/2),:,:].sum(1)
    print(x)
    r=(x>x.mean()/10).sum()/2
    s=scale * 1.0 / r
    print(r, s)
    return cv2.resize(img,(0,0), fx=s, fy=s), r, s

# %%
def scaleRadius_mask(img, scale, r, s) :
    x=img[int(img.shape[0]/2),:,:].sum(1)
    print(x)
#     r=(x>x.mean()/10).sum()/2
#     s=scale * 1.0 / r
#     print(r, s)
    return cv2.resize(img,(0,0), fx=s, fy=s)

# %%
plt.imshow(image2[:,:,2])
# cv2.waitKey(0)
plt.show()

# %%
scale = 500
a, r, s = scaleRadius(image, scale)
# a = image
# #s u b t r a c t l o c a l mean c o l o r
a=cv2.addWeighted (a , 4 , cv2.GaussianBlur( a , ( 0 , 0 ) , scale /30) , -4 , 128)
# #remove o u t e r 10%
b=np.zeros(a.shape)
cv2.circle(b,(int(a.shape[1]/2), int(a.shape[0] / 2)) , int(scale * 0.9 ) , ( 1 , 1 , 1 ) , -1, 8 , 0 )
# a=a*b+128*(1-b)
# a=a*b
# # cv2 . imw ri te ( s t r ( s c a l e )+"_"+f , a )
plt.imshow(a)
# cv2.waitKey(0)
plt.show()
# Out:
# [0 0 0 ... 0 0 0]
# 1705.0 0.2932551319648094

# %%
c = scaleRadius_mask(image2, scale, r, s)
# c=cv2.addWeighted (c , 4 , cv2.GaussianBlur( c , ( 0 , 0 ) , scale /30) , -4 , 128)
plt.imshow(c)
plt.show()
# Out:
# [0 0 0 ... 0 0 0]

# %%
c[c > 0] = 255

# %%
from sklearn.metrics import roc_curve, auc

t = torch.tensor([[[1, 0], [1, 1]], [[0, 0], [0, 1]]]).cuda()
# t = torch.flatten(t)
k = t.flatten().data.cpu().numpy()
fpr, tpr, _ = roc_curve(k, k)
roc_auc = auc(fpr,tpr)
roc_auc
# Out:
# 1.0

# %%
(unique, counts) = np.unique(c, return_counts=True)
frequencies = np.asarray((unique, counts)).T
unique
# Out:
# array([  0,   1,   5,  13,  17,  21,  22,  25,  27,  35,  36,  39,  40,
#         43,  65,  68,  70,  88, 101, 111, 136, 146, 147, 154, 156, 157,
#        162, 169, 172, 200, 203, 208, 210, 211, 213, 220, 221, 233, 244,
#        246, 251, 252, 255], dtype=uint8)

# %%
a = [1,2,3]
sum(a)/len(a)
# Out:
# 2.0
